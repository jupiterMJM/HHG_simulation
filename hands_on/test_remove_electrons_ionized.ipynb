# %% [markdown]
# In this file, one will try to artificially remove the electrons that drifts quickly away by using some FFT on the x-axis and filtering out the high-frequency component. Does it work? Idk, is it physically true? Probably not, but anyway let s try.

# %%
# importation of modules
# %matplotlib widget
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
with h5py.File(r"C:\maxence_data_results\HHG_simulation\HHG_simulation_linear_constant_1.0000e-02_5.0000e-02_8.0000e+02_1.0000e+14.h5", "r") as f:
    data = np.array(f["psi_history/psi_history_6"])

# %%
plt.figure()
plt.imshow(np.angle(data), aspect='auto', cmap='turbo')

# plt.clim(0, 0.01)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(data[1250, :], label='Real part')
# Out:
# c:\Users\ma5706ba\AppData\Local\anaconda3\envs\attolab\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\ma5706ba\AppData\Local\anaconda3\envs\attolab\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
spectrum = np.fft.fft(data, axis=1)
plt.figure()
plt.imshow(np.log(np.abs(spectrum)), aspect='auto', cmap='turbo')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(np.log(np.abs(spectrum[2000, :])), label="t=0")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
